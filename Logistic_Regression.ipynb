# %%
import warnings

# %%
warnings.filterwarnings("ignore")
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter("ignore", ConvergenceWarning)

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %%
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score,
    ConfusionMatrixDisplay,
    precision_recall_curve,
    roc_curve
)

# %%
who=pd.read_csv("/content/Logistic.csv")
data=who.copy()
data.head()
# Out:
#    age         workclass  fnlwgt  education  education_no_of_years  \
# 0   39         State-gov   77516  Bachelors                     13
# 1   50  Self-emp-not-inc   83311  Bachelors                     13
# 2   38           Private  215646    HS-grad                      9
# 3   53           Private  234721       11th                      7
# 4   28           Private  338409  Bachelors                     13
#
#   marital_status         occupation   race     sex  capital_gain  \
# 0  Never-married       Adm-clerical  White    Male          2174
# 1        married    Exec-managerial  White    Male             0
# 2    not_married  Handlers-cleaners  White    Male             0
# 3        married  Handlers-cleaners  Black    Male             0
# 4        married     Prof-specialty  Black  Female             0
#
#    capital_loss  working_hours_per_week native_contienent  salary
# 0             0                      40     north_america   <=50K
# 1             0                      13     north_america   <=50K
# 2             0                      40     north_america   <=50K
# 3             0                      40     north_america   <=50K
# 4             0                      40     north_america   <=50K

# %%
data.tail()
# Out:
#        age     workclass  fnlwgt   education  education_no_of_years  \
# 32526   27       Private  257302  Assoc-acdm                     12
# 32527   40       Private  154374     HS-grad                      9
# 32528   58       Private  151910     HS-grad                      9
# 32529   22       Private  201490     HS-grad                      9
# 32530   52  Self-emp-inc  287927     HS-grad                      9
#
#       marital_status         occupation   race     sex  capital_gain  \
# 32526        married       Tech-support  White  Female             0
# 32527        married  Machine-op-inspct  White    Male             0
# 32528    not_married       Adm-clerical  White  Female             0
# 32529  Never-married       Adm-clerical  White    Male             0
# 32530        married    Exec-managerial  White  Female         15024
#
#        capital_loss  working_hours_per_week native_contienent  salary
# 32526             0                      38     north_america   <=50K
# 32527             0                      40     north_america    >50K
# 32528             0                      40     north_america   <=50K
# 32529             0                      20     north_america   <=50K
# 32530             0                      40     north_america    >50K

# %%
data.shape
# Out:
# (32531, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32531 entries, 0 to 32530
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32531 non-null  int64
#  1   workclass               32531 non-null  object
#  2   fnlwgt                  32531 non-null  int64
#  3   education               32531 non-null  object
#  4   education_no_of_years   32531 non-null  int64
#  5   marital_status          32531 non-null  object
#  6   occupation              32531 non-null  object
#  7   race                    32531 non-null  object
#  8   sex                     32531 non-null  object
#  9   capital_gain            32531 non-null  int64
#  10  capital_loss            32531 non-null  int64
#  11  working_hours_per_week  32531 non-null  int64
#  12  native_contienent       32531 non-null  object
#  13  salary                  32531 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# education                 0
# education_no_of_years     0
# marital_status            0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# working_hours_per_week    0
# native_contienent         0
# salary                    0
# dtype: int64

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_no_of_years  capital_gain  \
# count  32531.000000  3.253100e+04           32531.000000  32531.000000
# mean      38.588362  1.897882e+05              10.081953   1078.642649
# std       13.637644  1.055642e+05               2.571842   7388.624210
# min       17.000000  1.228500e+04               1.000000      0.000000
# 25%       28.000000  1.178150e+05               9.000000      0.000000
# 50%       37.000000  1.783700e+05              10.000000      0.000000
# 75%       48.000000  2.370190e+05              12.000000      0.000000
# max       90.000000  1.484705e+06              16.000000  99999.000000
#
#        capital_loss  working_hours_per_week
# count  32531.000000            32531.000000
# mean      87.384341               40.441025
# std      403.137260               12.347506
# min        0.000000                1.000000
# 25%        0.000000               40.000000
# 50%        0.000000               40.000000
# 75%        0.000000               45.000000
# max     4356.000000               99.000000

# %%
data.drop(["capital_gain", "capital_loss"], axis=1, inplace=True)

# %%
numerical_col=data.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(20,30))
for i, variable in enumerate(numerical_col):
  plt.subplot(5,4,i+1)
  plt.boxplot(data[variable], whis=1.5)
  plt.tight_layout()
  plt.title(variable)

plt.show()

# %%
def treat_outliiers(df,col):
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)
  IQR=Q3-Q1
  Lower_Whisker=Q1-1.5*IQR
  Upper_Whisker=Q3-1.5*IQR
  df[col]=np.clip(df[col],Lower_Whisker,Upper_Whisker)
  return df

# %%
def treat_outliers_all(df, col_list):
  for c in col_list:
    df=treat_outliiers(df, c)
    return df

# %%
numerical_col=data.select_dtypes(include=np.number).columns.tolist()
data=treat_outliers_all(data, numerical_col)
plt.figure(figsize=(20,30))
for i, variable in enumerate(numerical_col):
  plt.subplot(5,4,i+1)
  plt.boxplot(data[variable], whis=1.5)
  plt.tight_layout()
  plt.title(variable)

plt.show()

# %%
data["salary"]=data["salary"].apply(lambda x:1 if x=="<=50K" else 0)

# %%
X=data.drop(["salary"], axis=1)
Y=data["salary"]

X=sm.add_constant(X)
X=pd.get_dummies(X, drop_first=True)
X=X.astype(float)
X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=0.30,random_state=1)

# %%
logit=sm.Logit(y_train,X_train.astype(float))
lg=logit.fit(disp=False)

print(lg.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 salary   No. Observations:                22771
# Model:                          Logit   Df Residuals:                    22721
# Method:                           MLE   Df Model:                           49
# Date:                Wed, 27 Nov 2024   Pseudo R-squ.:                     inf
# Time:                        12:16:12   Log-Likelihood:            -3.8368e-05
# converged:                      False   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# age                                -2.7269        nan        nan        nan         nan         nan
# fnlwgt                           1.607e-05      0.006      0.003      0.998      -0.011       0.011
# education_no_of_years              -0.4455        nan        nan        nan         nan         nan
# working_hours_per_week              0.3290    109.906      0.003      0.998    -215.083     215.741
# workclass_Local-gov                 0.0978   2.48e+04   3.95e-06      1.000   -4.85e+04    4.85e+04
# workclass_Never-worked             -0.0022        nan        nan        nan         nan         nan
# workclass_Private                   0.2809   2.46e+04   1.14e-05      1.000   -4.82e+04    4.82e+04
# workclass_Self-emp-inc              0.1027    2.5e+04   4.11e-06      1.000    -4.9e+04     4.9e+04
# workclass_Self-emp-not-inc          0.1959   2.47e+04   7.92e-06      1.000   -4.85e+04    4.85e+04
# workclass_State-gov                 0.1851   2.48e+04   7.46e-06      1.000   -4.86e+04    4.86e+04
# workclass_Unknown                   0.0660        nan        nan        nan         nan         nan
# workclass_Without-pay              -0.0005   1.34e+06  -3.92e-10      1.000   -2.63e+06    2.63e+06
# education_11th                      0.0219        nan        nan        nan         nan         nan
# education_12th                      0.0595        nan        nan        nan         nan         nan
# education_1st-4th                  -0.2252        nan        nan        nan         nan         nan
# education_5th-6th                  -0.0219        nan        nan        nan         nan         nan
# education_7th-8th                   0.0998        nan        nan        nan         nan         nan
# education_9th                      -0.4601        nan        nan        nan         nan         nan
# education_Assoc-acdm               -0.0302        nan        nan        nan         nan         nan
# education_Assoc-voc                -0.0643        nan        nan        nan         nan         nan
# education_Bachelors                -0.3407        nan        nan        nan         nan         nan
# education_Doctorate                -0.0315        nan        nan        nan         nan         nan
# education_HS-grad                   0.2721        nan        nan        nan         nan         nan
# education_Masters                  -0.0369        nan        nan        nan         nan         nan
# education_Preschool                -0.1893        nan        nan        nan         nan         nan
# education_Prof-school              -0.0533        nan        nan        nan         nan         nan
# education_Some-college              0.3275        nan        nan        nan         nan         nan
# marital_status_married             -0.0423   2105.142  -2.01e-05      1.000   -4126.045    4125.960
# marital_status_not_married         -0.1214   3643.567  -3.33e-05      1.000   -7141.381    7141.138
# occupation_Armed-Forces             0.0005   1.14e+07      4e-11      1.000   -2.24e+07    2.24e+07
# occupation_Craft-repair             0.1117   1.63e+04   6.84e-06      1.000    -3.2e+04     3.2e+04
# occupation_Exec-managerial         -0.1982   1.68e+04  -1.18e-05      1.000    -3.3e+04     3.3e+04
# occupation_Farming-fishing          0.0665   1.63e+04   4.08e-06      1.000    -3.2e+04     3.2e+04
# occupation_Handlers-cleaners       -0.0767    1.9e+04  -4.04e-06      1.000   -3.72e+04    3.72e+04
# occupation_Machine-op-inspct        0.0311   1.65e+04   1.88e-06      1.000   -3.24e+04    3.24e+04
# occupation_Other-service           -0.0170   1.66e+04  -1.02e-06      1.000   -3.25e+04    3.25e+04
# occupation_Priv-house-serv         -0.0191   1.79e+04  -1.07e-06      1.000    -3.5e+04     3.5e+04
# occupation_Prof-specialty          -0.2111   1.83e+04  -1.16e-05      1.000   -3.58e+04    3.58e+04
# occupation_Protective-serv          0.0025   1.65e+04    1.5e-07      1.000   -3.23e+04    3.23e+04
# occupation_Sales                    0.1622   1.68e+04   9.68e-06      1.000   -3.28e+04    3.28e+04
# occupation_Tech-support             0.0864   1.64e+04   5.27e-06      1.000   -3.22e+04    3.22e+04
# occupation_Transport-moving        -0.0316   1.65e+04  -1.92e-06      1.000   -3.23e+04    3.23e+04
# occupation_Unknown                  0.0638        nan        nan        nan         nan         nan
# race_Asian-Pac-Islander             0.0083   1.26e+05   6.58e-08      1.000   -2.46e+05    2.46e+05
# race_Black                          0.0813   1.26e+05   6.46e-07      1.000   -2.47e+05    2.47e+05
# race_Other                         -0.2063   1.44e+05  -1.43e-06      1.000   -2.83e+05    2.83e+05
# race_White                          0.0011   1.26e+05   9.07e-09      1.000   -2.46e+05    2.46e+05
# sex_Male                            0.1853   5953.097   3.11e-05      1.000   -1.17e+04    1.17e+04
# native_contienent_europe           -0.0829   2.24e+04   -3.7e-06      1.000   -4.39e+04    4.39e+04
# native_contienent_north_america    -0.0302   2.12e+04  -1.42e-06      1.000   -4.16e+04    4.16e+04
# native_contienent_other             0.0994   2.18e+04   4.57e-06      1.000   -4.27e+04    4.27e+04
# native_contienent_south_america     0.0025   2.36e+04   1.07e-07      1.000   -4.62e+04    4.62e+04
# ===================================================================================================
#
# Complete Separation: The results show that there iscomplete separation or perfect prediction.
# In this case the Maximum Likelihood Estimator does not exist and the parameters
# are not identified.

# %%
def model_performance_classification_statsmodels(model,predictors,target,threshold=0.5):
  pred_temp=model.predict(predictors)>threshold
  pred=np.round(pred_temp)
  acc=accuracy_score(target, pred)
  recall=recall_score(target, pred)
  precision=precision_score(target, pred)
  f1=f1_score(target, pred)
  df_perf=pd.DataFrame({"Acuracy":acc, "Recall": recall, "Precision":precision,"F1":f1}, index=[0])
  return df_perf

print("Training performance:")
model_performance_classification_statsmodels(lg,X_train,y_train)
# Out:
# Training performance:
#    Acuracy  Recall  Precision   F1
# 0      1.0     0.0        0.0  0.0

# %%
vif_series = pd.Series(
[variance_inflation_factor(X_train.values, 1) for i in range(X_train.shape[1])],

index=X_train.columns,

dtype=float,
)
print("Series before feature selection: \n\n{}\n".format(vif_series))
# Out:
# Series before feature selection:
#
# age                                1.030385
# fnlwgt                             1.030385
# education_no_of_years              1.030385
# working_hours_per_week             1.030385
# workclass_Local-gov                1.030385
# workclass_Never-worked             1.030385
# workclass_Private                  1.030385
# workclass_Self-emp-inc             1.030385
# workclass_Self-emp-not-inc         1.030385
# workclass_State-gov                1.030385
# workclass_Unknown                  1.030385
# workclass_Without-pay              1.030385
# education_11th                     1.030385
# education_12th                     1.030385
# education_1st-4th                  1.030385
# education_5th-6th                  1.030385
# education_7th-8th                  1.030385
# education_9th                      1.030385
# education_Assoc-acdm               1.030385
# education_Assoc-voc                1.030385
# education_Bachelors                1.030385
# education_Doctorate                1.030385
# education_HS-grad                  1.030385
# education_Masters                  1.030385
# education_Preschool                1.030385
# education_Prof-school              1.030385
# education_Some-college             1.030385
# marital_status_married             1.030385
# marital_status_not_married         1.030385
# occupation_Armed-Forces            1.030385
# occupation_Craft-repair            1.030385
# occupation_Exec-managerial         1.030385
# occupation_Farming-fishing         1.030385
# occupation_Handlers-cleaners       1.030385
# occupation_Machine-op-inspct       1.030385
# occupation_Other-service           1.030385
# occupation_Priv-house-serv         1.030385
# occupation_Prof-specialty          1.030385
# occupation_Protective-serv         1.030385
# occupation_Sales                   1.030385
# occupation_Tech-support            1.030385
# occupation_Transport-moving        1.030385
# occupation_Unknown                 1.030385
# race_Asian-Pac-Islander            1.030385
# race_Black                         1.030385
# race_Other                         1.030385
# race_White                         1.030385
# sex_Male                           1.030385
# native_contienent_europe           1.030385
# native_contienent_north_america    1.030385
# native_contienent_other            1.030385
# native_contienent_south_america    1.030385
# dtype: float64

# %%
X_train1 = X_train.drop("occupation_Unknown", axis=1)
vif_series2 = pd.Series(
[variance_inflation_factor(X_train1.values, i) for i in range(X_train1.shape[1])],
index=X_train1.columns,
)
print("Series before feature selection: \n\n{}\n".format(vif_series2))
# Out:
# Series before feature selection:
#
# age                                 0.000000
# fnlwgt                              1.030385
# education_no_of_years                    inf
# working_hours_per_week              1.196517
# workclass_Local-gov                 3.040496
# workclass_Never-worked              1.012128
# workclass_Private                   7.684165
# workclass_Self-emp-inc              2.215299
# workclass_Self-emp-not-inc          3.485758
# workclass_State-gov                 2.315118
# workclass_Unknown                   3.048350
# workclass_Without-pay               1.015621
# education_11th                           inf
# education_12th                           inf
# education_1st-4th                        inf
# education_5th-6th                        inf
# education_7th-8th                        inf
# education_9th                            inf
# education_Assoc-acdm                     inf
# education_Assoc-voc                      inf
# education_Bachelors                      inf
# education_Doctorate                      inf
# education_HS-grad                        inf
# education_Masters                        inf
# education_Preschool                      inf
# education_Prof-school                    inf
# education_Some-college                   inf
# marital_status_married              1.588027
# marital_status_not_married          1.374625
# occupation_Armed-Forces             1.010045
# occupation_Craft-repair             2.132699
# occupation_Exec-managerial          2.034643
# occupation_Farming-fishing          1.403227
# occupation_Handlers-cleaners        1.436428
# occupation_Machine-op-inspct        1.576768
# occupation_Other-service            1.748474
# occupation_Priv-house-serv          1.054111
# occupation_Prof-specialty           2.316164
# occupation_Protective-serv          1.252240
# occupation_Sales                    1.888081
# occupation_Tech-support             1.239200
# occupation_Transport-moving         1.508019
# race_Asian-Pac-Islander             5.304041
# race_Black                         10.186337
# race_Other                          1.877352
# race_White                         13.484386
# sex_Male                            1.510036
# native_contienent_europe            2.422705
# native_contienent_north_america     5.249351
# native_contienent_other             2.330891
# native_contienent_south_america     1.328657
# dtype: float64

# %%
X_train2 = X_train.drop("education_no_of_years", axis=1)
vif_series3 = pd.Series(
[variance_inflation_factor(X_train2.values, i) for i in range(X_train2.shape[1])],
index=X_train2.columns,
)
print("Series before feature selection: \n\n{}\n".format(vif_series2))
# Out:
# Series before feature selection:
#
# age                                 0.000000
# fnlwgt                              1.030385
# education_no_of_years                    inf
# working_hours_per_week              1.196517
# workclass_Local-gov                 3.040496
# workclass_Never-worked              1.012128
# workclass_Private                   7.684165
# workclass_Self-emp-inc              2.215299
# workclass_Self-emp-not-inc          3.485758
# workclass_State-gov                 2.315118
# workclass_Unknown                   3.048350
# workclass_Without-pay               1.015621
# education_11th                           inf
# education_12th                           inf
# education_1st-4th                        inf
# education_5th-6th                        inf
# education_7th-8th                        inf
# education_9th                            inf
# education_Assoc-acdm                     inf
# education_Assoc-voc                      inf
# education_Bachelors                      inf
# education_Doctorate                      inf
# education_HS-grad                        inf
# education_Masters                        inf
# education_Preschool                      inf
# education_Prof-school                    inf
# education_Some-college                   inf
# marital_status_married              1.588027
# marital_status_not_married          1.374625
# occupation_Armed-Forces             1.010045
# occupation_Craft-repair             2.132699
# occupation_Exec-managerial          2.034643
# occupation_Farming-fishing          1.403227
# occupation_Handlers-cleaners        1.436428
# occupation_Machine-op-inspct        1.576768
# occupation_Other-service            1.748474
# occupation_Priv-house-serv          1.054111
# occupation_Prof-specialty           2.316164
# occupation_Protective-serv          1.252240
# occupation_Sales                    1.888081
# occupation_Tech-support             1.239200
# occupation_Transport-moving         1.508019
# race_Asian-Pac-Islander             5.304041
# race_Black                         10.186337
# race_Other                          1.877352
# race_White                         13.484386
# sex_Male                            1.510036
# native_contienent_europe            2.422705
# native_contienent_north_america     5.249351
# native_contienent_other             2.330891
# native_contienent_south_america     1.328657
# dtype: float64

# %%
logit2=sm.Logit(y_train, X_train2.astype(float))
lg2=logit2.fit(disp=False)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-42-ca156aea0357> in <cell line: 2>()
#       1 logit2=sm.Logit(y_train, X_train2.astype(float))
# ----> 2 lg2=logit2.fit(disp=False)
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    2599     def fit(self, start_params=None, method='newton', maxiter=35,
#    2600             full_output=1, disp=1, callback=None, **kwargs):
# -> 2601         bnryfit = super().fit(start_params=start_params,
#    2602                               method=method,
#    2603                               maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     241             pass  # TODO: make a function factory to have multiple call-backs
#     242
# --> 243         mlefit = super().fit(start_params=start_params,
#     244                              method=method,
#     245                              maxiter=maxiter,
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     580             Hinv = cov_params_func(self, xopt, retvals)
#     581         elif method == 'newton' and full_output:
# --> 582             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     583         elif not skip_hessian:
#     584             H = -1 * self.hessian(xopt)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     559     signature = 'D->D' if isComplexType(t) else 'd->d'
#     560     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562     return wrap(ainv.astype(result_t, copy=False))
#     563
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#     110
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#     113
#     114 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
